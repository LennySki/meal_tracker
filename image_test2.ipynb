# %%
from matplotlib import Image
import matplotlib.pyplot as plt

image = Image.open("steak.jpeg")
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from matplotlib import Image
#       2 import matplotlib.pyplot as plt
#       4 image = Image.open("steak.jpeg")
#
# ImportError: cannot import name 'Image' from 'matplotlib' (/opt/anaconda3/envs/meal_tracker_env/lib/python3.9/site-packages/matplotlib/__init__.py)

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("steak.jpeg")
plt.imshow(image)
plt.axis("off")
plt.show()
