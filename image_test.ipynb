# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open(Cheeseburger.jpg)
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from PIL import Image
#       2 import matplotlib.pyplot as plt
# ----> 4 image = Image.open(Cheeseburger.jpg)
#       5 plt.imshow(image)
#       6 plt.axis("off")
#
# NameError: name 'Cheeseburger' is not defined

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("Cheeseburger.jpg")
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import matplot.lib.pyplot as plt

image = Image.open("Cheeseburger,jpg")
plt.imshow(image)
plt.axis("off")
Image.resize(224, 224)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from PIL import Image
# ----> 2 import matplot.lib.pyplot as plt
#       4 image = Image.open("Cheeseburger,jpg")
#       5 plt.imshow(image)
#
# ModuleNotFoundError: No module named 'matplot'

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("Cheeseburger,jpg")
plt.imshow(image)
plt.axis("off")
Image.resize(224, 224)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from PIL import Image
#       2 import matplotlib.pyplot as plt
# ----> 4 image = Image.open("Cheeseburger,jpg")
#       5 plt.imshow(image)
#       6 plt.axis("off")
#
# File /opt/anaconda3/envs/meal_tracker_env/lib/python3.9/site-packages/PIL/Image.py:3465, in open(fp, mode, formats)
#    3462     filename = os.fspath(fp)
#    3464 if filename:
# -> 3465     fp = builtins.open(filename, "rb")
#    3466     exclusive_fp = True
#    3467 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Cheeseburger,jpg'

# %%
from PIL import Image
import matplot.lib.pyplot as plt

image = Image.open("Cheeseburger.jpg")
plt.imshow(image)
plt.axis("off")
Image.resize(224, 224)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from PIL import Image
# ----> 2 import matplot.lib.pyplot as plt
#       4 image = Image.open("Cheeseburger.jpg")
#       5 plt.imshow(image)
#
# ModuleNotFoundError: No module named 'matplot'

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("Cheeseburger.jpg")
plt.imshow(image)
plt.axis("off")
Image.resize(224, 224)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 7
#       5 plt.imshow(image)
#       6 plt.axis("off")
# ----> 7 Image.resize(224, 224)
#       8 plt.show()
#
# AttributeError: module 'PIL.Image' has no attribute 'resize'

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("Cheeseburger.jpg")
resized_image = image.resize((224, 224))
plt.imshow(resized_image)
plt.axis("off")
plt.show()
